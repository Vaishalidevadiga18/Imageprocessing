# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO

def show_image(img, title="Image"):
    # Convert BGR to RGB for matplotlib
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(10, 6))
    plt.imshow(img_rgb)
    plt.title(title)
    plt.axis('off')
    plt.show()

def detect_with_haar(image_path):
    face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)

    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x + w, y + h), (255, 0, 0), 2)

    show_image(img, "Haar Cascade Detection")

def detect_with_hog(image_path):
    hog = cv2.HOGDescriptor()
    hog.setSVMDetector(cv2.HOGDescriptor_getDefaultPeopleDetector())
    img = cv2.imread(image_path)
    img = cv2.resize(img, (640, 480))  # Resize for better speed

    (boxes, weights) = hog.detectMultiScale(img, winStride=(8, 8), padding=(8, 8), scale=1.05)

    for (x, y, w, h) in boxes:
        cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    show_image(img, "HOG + SVM Detection")

def detect_with_yolo(image_path):
    model = YOLO('yolov8n.pt')  # Automatically downloads on first use
    results = model(image_path)
    annotated_img = results[0].plot()
    show_image(annotated_img, "YOLOv8 Detection")

# --------------- MAIN ----------------
if __name__ == "__main__":
    image_path = r"C:\Users\HP\OneDrive\Pictures\yolo.jpg"  # Change this to your actual image path

    print("Choose detection method:")
    print("1 - Haar Cascades")
    print("2 - HOG + SVM")
    print("3 - YOLOv8")

    choice = input("Enter your choice (1/2/3): ").strip()

    if choice == '1':
        detect_with_haar(image_path)
    elif choice == '2':
        detect_with_hog(image_path)
    elif choice == '3':
        detect_with_yolo(image_path)
    else:
        print("Invalid choice!")
# Out:
# WARNING torchvision==0.22 is incompatible with torch==2.5.
# Run 'pip install torchvision==0.20' to fix torchvision or 'pip install -U torch torchvision' to update both.
# For a full compatibility table see https://github.com/pytorch/vision#installation
# Choose detection method:
# 1 - Haar Cascades
# 2 - HOG + SVM
# 3 - YOLOv8
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt'...
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:1276, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1275 """Send a complete request to the server."""
# -> 1276 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:1322, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1321     body = _encode(body, 'body')
# -> 1322 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:1271, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1270     raise CannotSendHeader()
# -> 1271 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:1031, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1030 del self._buffer[:]
# -> 1031 self.send(msg)
#    1033 if message_body is not None:
#    1034
#    1035     # create a consistent interface to message_body
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:969, in HTTPConnection.send(self, data)
#     968 if self.auto_open:
# --> 969     self.connect()
#     970 else:
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:1441, in HTTPSConnection.connect(self)
#    1439 "Connect to a host on a given (SSL) port."
# -> 1441 super().connect()
#    1443 if self._tunnel_host:
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\http\client.py:940, in HTTPConnection.connect(self)
#     939 sys.audit("http.client.connect", self, self.host, self.port)
# --> 940 self.sock = self._create_connection(
#     941     (self.host,self.port), self.timeout, self.source_address)
#     942 self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\socket.py:824, in create_connection(address, timeout, source_address)
#     823 err = None
# --> 824 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     825     af, socktype, proto, canonname, sa = res
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\utils\downloads.py:351, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     350 if method == "torch":
# --> 351     torch.hub.download_url_to_file(url, f, progress=progress)
#     352 else:
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\torch\hub.py:708, in download_url_to_file(url, dst, hash_prefix, progress)
#     685 def download_url_to_file(
#     686     url: str,
#     687     dst: str,
#     688     hash_prefix: Optional[str] = None,
#     689     progress: bool = True,
#     690 ) -> None:
#     691     r"""Download object at the given URL to a local path.
#     692
#     693     Args:
#     694         url (str): URL of the object to download
#     695         dst (str): Full path where object will be saved, e.g. ``/tmp/temporary_file``
#     696         hash_prefix (str, optional): If not None, the SHA256 downloaded file should start with ``hash_prefix``.
#     697             Default: None
#     698         progress (bool, optional): whether or not to display a progress bar to stderr
#     699             Default: True
#     700
#     701     Example:
#     702         >>> # xdoctest: +REQUIRES(env:TORCH_DOCTEST_HUB)
#     703         >>> # xdoctest: +REQUIRES(POSIX)
#     704         >>> torch.hub.download_url_to_file(
#     705         ...     "https://s3.amazonaws.com/pytorch/models/resnet18-5c106cde.pth",
#     706         ...     "/tmp/temporary_file",
#     707         ... )
# --> 708
#     709     """
#     710     file_size = None
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1350 except OSError as err: # timeout error
# -> 1351     raise URLError(err)
#    1352 r = h.getresponse()
#
# URLError: <urlopen error [Errno 11001] getaddrinfo failed>
#
# The above exception was the direct cause of the following exception:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[2], line 60
#      58     detect_with_hog(image_path)
#      59 elif choice == '3':
# ---> 60     detect_with_yolo(image_path)
#      61 else:
#      62     print("Invalid choice!")
#
# Cell In[2], line 39, in detect_with_yolo(image_path)
#      38 def detect_with_yolo(image_path):
# ---> 39     model = YOLO('yolov8n.pt')  # Automatically downloads on first use
#      40     results = model(image_path)
#      41     annotated_img = results[0].plot()
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\models\yolo\model.py:79, in YOLO.__init__(self, model, task, verbose)
#      76     self.__dict__ = new_instance.__dict__
#      77 else:
#      78     # Continue with default YOLO initialization
# ---> 79     super().__init__(model=model, task=task, verbose=verbose)
#      80     if hasattr(self.model, "model") and "RTDETR" in self.model.model[-1]._get_name():  # if RTDETR head
#      81         from ultralytics import RTDETR
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:151, in Model.__init__(self, model, task, verbose)
#     149     self._new(model, task=task, verbose=verbose)
#     150 else:
# --> 151     self._load(model, task=task)
#     153 # Delete super().training for accessing self.model.training
#     154 del self.training
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\engine\model.py:295, in Model._load(self, weights, task)
#     292 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolo11n -> yolo11n.pt
#     294 if str(weights).rpartition(".")[-1] == "pt":
# --> 295     self.model, self.ckpt = attempt_load_one_weight(weights)
#     296     self.task = self.model.args["task"]
#     297     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:1549, in attempt_load_one_weight(weight, device, inplace, fuse)
#    1535 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#    1536     """
#    1537     Load a single model weights.
#    1538
#    (...)
#    1547         ckpt (dict): Model checkpoint dictionary.
#    1548     """
# -> 1549     ckpt, weight = torch_safe_load(weight)  # load ckpt
#    1550     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#    1551     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\nn\tasks.py:1425, in torch_safe_load(weight, safe_only)
#    1422 from ultralytics.utils.downloads import attempt_download_asset
#    1424 check_suffix(file=weight, suffix=".pt")
# -> 1425 file = attempt_download_asset(weight)  # search online if missing locally
#    1426 try:
#    1427     with temporary_modules(
#    1428         modules={
#    1429             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#    1437         },
#    1438     ):
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\utils\downloads.py:468, in attempt_download_asset(file, repo, release, **kwargs)
#     465         safe_download(url=url, file=file, min_bytes=1e5, **kwargs)
#     467 elif repo == GITHUB_ASSETS_REPO and name in GITHUB_ASSETS_NAMES:
# --> 468     safe_download(url=f"{download_url}/{release}/{name}", file=file, min_bytes=1e5, **kwargs)
#     470 else:
#     471     tag, assets = get_github_assets(repo, release)
#
# File c:\Users\VAISHALI\AppData\Local\Programs\Python\Python310\lib\site-packages\ultralytics\utils\downloads.py:372, in safe_download(url, file, dir, unzip, delete, curl, retry, min_bytes, exist_ok, progress)
#     370 except Exception as e:
#     371     if i == 0 and not is_online():
# --> 372         raise ConnectionError(emojis(f"❌  Download failure for {uri}. Environment is not online.")) from e
#     373     elif i >= retry:
#     374         raise ConnectionError(emojis(f"❌  Download failure for {uri}. Retry limit reached.")) from e
#
# ConnectionError:   Download failure for https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt. Environment is not online.
